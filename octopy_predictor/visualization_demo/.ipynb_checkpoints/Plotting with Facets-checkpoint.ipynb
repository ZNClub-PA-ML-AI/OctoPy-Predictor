# %% [markdown]
# # Google's Facets for Visualization

# %% [markdown]
# ## Load Data

# %% [markdown]
# Enter local filepath

# %%
filepath = '../data/mutual_funds' +'.csv'

# %%
import os
os.path.exists(filepath)
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv(
    filepath,
    na_values="",
    nrows=2000, 
    encoding = "ISO-8859-1")
df.shape
# Out:
# (2000, 56)

# %% [markdown]
# ## Facets DeepDive

# %%
from IPython.core.display import display, HTML

HTML_TEMPLATE = """<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=df.to_json(orient='records'))
display(HTML(html))
# Out:
# <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data = [{"fund_name":"Deutsche Real Assets A","category":"World Allocation","fund_family":"Deutsche Asset Management","investment":"Blend","size":"Large","total_net_assets":486740000.0,"currency":"USD","net_annual_expenses":1.22,"morningstar_rating":2,"inception_date":"29\/07\/2007","portfolio_cash":3.51,"portfolio_cash Amount":17084574.0,"portfolio_stocks":64.5,"portfolio_stocks amount":313947300.0,"portfolio_bonds":15.12,"portfolio_bonds amount":73595088.0,"portfolio_others":16.88,"portfolio_others amunt":82161712.0,"portfolio_preferred":0.0,"portfolio_preferred amount":0,"portfolio_convertable":0.0,"portfolio_convertable amount":0,"sectors_basic_materials":11.6,"sectors_basic_materials amount":56461840,"sectors_consumer_cyclical":1.17,"sectors_consumer_cyclical amount":5694858,"sectors_financial_services":0.0,"sectors_financial_services amount":0,"sectors_real_estate":30.81,"sectors_real_estate amount":149964594,"sectors_consumer_defensive":0.96,"sectors_consumer_defensive amount":4672704,"sectors_healthcare":0.0,"sectors_healthcare amount ":0,"sectors_utilities":17.22,"sectors_utilities amount":83816628,"sectors_communication_services":5.61,"sectors_communication_services amount":27306114,"sectors_energy":18.57,"sectors_energy amount":90387618,"sectors_industrials":12.58,"sectors_industrials amount":61231892,"sectors_technology":1.49,"sectors_technology amount":7252426,"price_earning":22.68,"morningstar_return_rating":2,"returns_ytd":1.15,"returns_2017":14.67,"returns_2016":4.01,"morningstar_risk_rating":3,"alpha_3y":-1.96,"beta_3y":0.84,"mean_annual_return_3y":0.26,"standard_deviation_3y":7.16,"sharpe_ratio_3y":0.35,"treynor_ratio_3y":2.7},{"fund_name":"Aberdeen Income Builder A","category":"Large Blend","fund_family":"Aberdeen","investment":"Value","size":"Large","total_net_assets":9980000.0,"currency":"USD","net_annual_expenses":1.44,"morningstar_rating":2,"inception_date":"29\/12\/2011","portfolio_cash":1.78,"portfolio_cash Amount":177644.0,"portfolio_stocks":98.22,"portfolio_stocks amount":9802356.0,"portfolio_bonds":0.0,"portfolio_bonds amount":0.0,"portfolio_others":0.0,"portfolio_others amunt":0.0,"portfolio_preferred":0.0,"portfolio_preferred amount":0,"portfolio_convertable":0.0,"portfolio_convertable amount":0,"sectors_basic_materials":2.82,"sectors_basic_materials amount":13726068,"sectors_consumer_cyclical":11.76,"sectors_consumer_cyclical amount":57240624,"sectors_financial_services":16.58,"sectors_financial_services amount":80701492,"sectors_real_estate":2.04,"sectors_real_estate amount":9929496,"sectors_consumer_defensive":5.94,"sectors_consumer_defensive amount":28912356,"sectors_healthcare":12.83,"sectors_healthcare amount ":62448742,"sectors_utilities":3.89,"sectors_utilities amount":18934186,"sectors_communication_services":4.9,"sectors_communication_services amount":23850260,"sectors_energy":5.56,"sectors_energy amount":27062744,"sectors_industrials":10.22,"sectors_industrials amount":49744828,"sectors_technology":23.48,"sectors_technology amount":114286552,"price_earning":14.49,"morningstar_return_rating":2,"returns_ytd":-1.16,"returns_2017":17.05,"returns_2016":11.26,"morningstar_risk_rating":3,"alpha_3y":-4.84,"beta_3y":1.0,"mean_annual_return_3y":0.51,"standard_deviation_3y":10.62,"sharpe_ratio_3y":0.51,"treynor_ratio_3y":5.04},{"fund_name":"Thrivent Large Cap Growth A","category":"Large Growth","fund_family":"Thrivent","investment":"Growth","size":"Large","total_net_assets":997620000.0,"currency":"USD","net_annual_expenses":1.2,"morningstar_rating":3,"inception_date":"28\/10\/1999","portfolio_cash":5.37,"portfolio_cash Amount":53572194.0,"portfolio_stocks":94.63,"portfolio_stocks amount":944047806.0,"portfolio_bonds":0.0,"portfolio_bonds amount":0.0,"portfolio_others":0.0,"portfolio_others amunt":0.0,"portfolio_preferred":0.0,"portfolio_preferred amount":0,"portfolio_convertable":0.0,"portfolio_convertable amount":0,"sectors_basic_materials":0.0,"sectors_basic_materials amount":0,"se ...
