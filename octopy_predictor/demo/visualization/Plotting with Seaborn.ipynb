# %% [markdown]
# # Plotting with Seaborn
#
# [Seaborn]() [Gallery]()

# %% [markdown]
# ## Quick Demo

# %% [markdown]
# ### Important imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import logging
logging.getLogger('seaborn').setLevel(logging.ERROR)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Sample datasets

# %%
 sns.get_dataset_names()
# Out:
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('car_crashes')
df.head(2)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK

# %% [markdown]
# ## Co-relation Matrix

# %%
sns.heatmap(df.corr(),
            annot=True,
            linewidths=0.4,
            annot_kws={"size": 10})

# %%
df.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %%
# intervals = [col for col in df.columns.values.tolist() if len(df[col].unique()) > df.shape[0] // 2] 
categorial_column_types = ['object','datetime']
intervals = df.select_dtypes(exclude=categorial_column_types).columns.values.tolist()
categorials = df.select_dtypes(include=categorial_column_types).columns.values.tolist()
intervals, categorials
# Out:
# (['total',
#   'speeding',
#   'alcohol',
#   'not_distracted',
#   'no_previous',
#   'ins_premium',
#   'ins_losses'],
#  ['abbrev'])

# %%
# len(df['abbrev'].unique()) , df.shape[0] // 2
sns.countplot(df[categorials[0]])

# %%
sns.jointplot(x='alcohol', y='log(speeding)', data=df, kind='hex')
sns.jointplot(x='alcohol', y='log(speeding)', data=df, kind='scatter')
# Out:
# --------------------------------------------------------------------------
# ValueError                               Traceback (most recent call last)
# <ipython-input-8-7e01a2bbcee1> in <module>
# ----> 1 sns.jointplot(x='alcohol', y='log(speeding)', data=df, kind='hex')
#       2 sns.jointplot(x='alcohol', y='log(speeding)', data=df, kind='scatter')
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2282     grid = JointGrid(x, y, data, dropna=dropna,
#    2283                      height=height, ratio=ratio, space=space,
# -> 2284                      xlim=xlim, ylim=ylim)
#    2285
#    2286     # Plot the data using the grid
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size)
#    1707             if isinstance(var, string_types):
#    1708                 err = "Could not interpret input '{}'".format(var)
# -> 1709                 raise ValueError(err)
#    1710
#    1711         # Find the names of the variables
#
# ValueError: Could not interpret input 'log(speeding)'

# %%
df['log(speeding)'] = df['speeding'].apply(np.log)
df.head(2)
