# %% [markdown]
# ### test drive for classes

# %%
import context
context.init_dependencies()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9b44d1d42f4a> in <module>()
# ----> 1 import context
#       2 context.init_dependencies()
#
# C:\Users\Augus\dev\Projects\OctoPy-Predictor\octopy_predictor\main\context.py in <module>()
#      19 HTTP_PORT = config['WEB'].getint('HTTP_PORT')
#      20 DEBUG_MODE = config['FLAG'].getboolean('DEBUG_MODE')
# ---> 21 ALLOWED_EXTENSIONS = set(config['SYSTEM']['ALLOWED_EXTENSIONS'].split(LIST_DELIMITTER))
#      22 VISUALIZER = config['DEFAULT_COMPONENT']['VISUALIZER']
#      23
#
# NameError: name 'LIST_DELIMITTER' is not defined

# %%
viz = context.app_context['service'].visualizer
gat = context.app_context['service'].datagatherer

# %%
PATH = r'..\data\nifty50.csv'
PATH = r'..\data\titanic-test.csv'

# %%
df = gat.read(PATH)
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
'''time_series'''
#==============================================================================
column_dtype_groups = df.columns.to_series().groupby(df.dtypes).groups
column_dtype_dict = {k.name:v for k,v in column_dtype_groups.items()}
viz.time_series(df, column_dtype_dict['float64'])
#==============================================================================

# %%
'''histogram'''
viz.histogram(df = df, column = 'Fare')

# %%
import numpy as np
np.array([10]*4).tolist()
# Out:
# [10, 10, 10, 10]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
# ts = ts.cumsum()
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
# df = df.cumsum()
df.head()
df.cumsum()
# Out:
#                    A          B          C          D
# 2000-01-01 -0.151482  -0.816089   0.937234   0.379570
# 2000-01-02 -0.045792  -1.822046   2.533175   0.590578
# 2000-01-03 -1.410041  -1.696823   3.581726   0.202134
# 2000-01-04 -1.986976  -2.149041   3.930441   0.883351
# 2000-01-05  1.079755  -0.847717   2.308534   0.968369
# 2000-01-06 -0.377621  -3.011445   2.326612   2.781887
# 2000-01-07 -2.888383  -2.833635  -0.017766   3.479370
# 2000-01-08 -2.913002  -1.855908   0.399622   2.153984
# 2000-01-09 -1.773724  -1.100211  -0.450289   1.986795
# 2000-01-10 -1.943785   0.054093  -0.097846   1.879339
# 2000-01-11 -3.272843  -1.600322  -0.921989   2.167489
# 2000-01-12 -5.932650  -0.937138  -1.532610   3.834338
# 2000-01-13 -5.794354  -0.699630  -3.214756   1.287373
# 2000-01-14 -6.799968  -0.117726  -5.226223   1.428319
# 2000-01-15 -8.166114  -1.975748  -4.492020   2.161329
# 2000-01-16 -5.642079  -2.745152  -4.196739   2.005587
# 2000-01-17 -6.938920  -3.426173  -3.518225   1.426773
# 2000-01-18 -5.368641  -3.523469  -2.546880   2.632963
# 2000-01-19 -4.967364  -5.210609  -1.637138   4.182388
# 2000-01-20 -5.564183  -5.959343  -1.054181   1.453811
